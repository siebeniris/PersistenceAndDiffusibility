# %%
import pandas as pd
import numpy as np
from itertools import product
from tqdm import tqdm
import networkx as nx
import pickle

from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
stage1= "../data/stage1"

# %% [markdown]
# # 1. Load files

# %% [markdown]
# ## load phonology

# %%
df_phon = pd.read_csv(f"{stage1}/pmiLanguageDistances.csv", sep="\t")

# %%
df_phon
# Out:
#                         JaegerCode1                       JaegerCode2
# 0        NC.BANTOID.A53_BAFIA_RIKPA               TNG.MADANG.ABASAKUR  \
# 1        NC.BANTOID.A53_BAFIA_RIKPA            Sep.UPPER_SEPIK.ABAU_2
# 2        NC.BANTOID.A53_BAFIA_RIKPA     NWC.NORTHWEST_CAUCASIAN.ABAZA
# 3        NC.BANTOID.A53_BAFIA_RIKPA    NWC.NORTHWEST_CAUCASIAN.ABKHAZ
# 4        NC.BANTOID.A53_BAFIA_RIKPA  NWC.NORTHWEST_CAUCASIAN.ABKHAZ_2
# ...                             ...                               ...
# 4331998           NC.BANTOID.ZIGULA               NC.BANTOID.ZOOMBO_2
# 4331999           NC.BANTOID.ZIGULA               NC.BANTOID.ZOOMBO_3
# 4332000           NC.BANTOID.ZIGULA               NC.BANTOID.ZOOMBO_4
# 4332001           NC.BANTOID.ZIGULA                   NC.BANTOID.ZULU
# 4332002           NC.BANTOID.ZIGULA                 NC.BANTOID.ZULU_2
#
#         Glottocode1 Glottocode2       PMI
# 0          bafi1243    pall1244  0.839955
# 1          bafi1243    abau1245  0.877663
# 2          bafi1243    abaz1241  0.883918
# 3          bafi1243    abkh1244  0.882524
# 4          bafi1243    abkh1244  0.880243
# ...             ...         ...       ...
# 4331998    zigu1244    koon1244  0.671316
# 4331999    zigu1244    koon1244  0.700825
# 4332000    zigu1244    koon1244  0.733510
# 4332001    zigu1244    zulu1248  0.712642
# 4332002    zigu1244    zulu1248  0.713499
#
# [2197565 rows x 5 columns]

# %%
df_phon = df_phon.dropna()

# %%
phon_dict = dict()

langs=[]
for lang1, lang2, pmi in zip(df_phon["Glottocode1"], df_phon["Glottocode2"], df_phon["PMI"]):
    l1,l2 = sorted([lang1, lang2])
    if l1!=l2:
        phon_dict[(l1,l2)]= pmi
        langs.append(l1)
        langs.append(l2)
    else:
        print(l1,l2,pmi)

# %%
len(set(langs))
# Out:
# 1562

# %%
phon_dict[('bafi1243', 'zaca1242')]
# Out:
# 0.863057842180655

# %% [markdown]
# ## load language info

# %%
from ast import literal_eval

# %%
language_all = pd.read_csv("../data/languages/languages_dataframe.csv", index_col=1).drop(["Unnamed: 0"],axis=1)

# %%
langd= pd.read_csv("../data/languages/languages_family_area.csv", index_col=0).to_dict(orient="index")

# %%
df_lang = pd.read_csv(f"{stage1}/languages_info.csv", index_col=0)

# %%
lang_dict = df_lang.to_dict(orient="index")

# %%
langd
# Out:
# {'musk1252': {'name': 'Muskogean',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'maba1274': {'name': 'Maban',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'guri1248': {'name': 'Guriaso',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -3.5718,
#   'longitude': 141.597,
#   'iso639-3': 'grx'},
#  'pawa1255': {'name': 'Pawaia',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -6.88021,
#   'longitude': 145.081,
#   'iso639-3': 'pwa'},
#  'bora1262': {'name': 'Boran',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'guam1236': {'name': 'Guamo',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 8.2351027,
#   'longitude': -67.4018753,
#   'iso639-3': nan},
#  'rash1249': {'name': 'Rashad',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'dama1272': {'name': 'Damal',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.17345,
#   'longitude': 137.496,
#   'iso639-3': 'uhn'},
#  'puqu1242': {'name': 'Puquina',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -15.8992,
#   'longitude': -69.9611,
#   'iso639-3': 'puq'},
#  'kusu1250': {'name': 'Kusunda',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 28.33,
#   'longitude': 82.6,
#   'iso639-3': 'kgg'},
#  'mirn1241': {'name': 'Mirndi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kuli1252': {'name': 'Kuliak',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'vile1241': {'name': 'Vilela',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -27.4063,
#   'longitude': -58.9661,
#   'iso639-3': 'vil'},
#  'tuni1252': {'name': 'Tunica',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 30.9888,
#   'longitude': -92.5403,
#   'iso639-3': 'tun'},
#  'sent1261': {'name': 'Sentanic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'arut1244': {'name': 'Arutani',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 4.0673594,
#   'longitude': -62.8676118,
#   'iso639-3': 'atx'},
#  'yetf1238': {'name': 'Yetfa',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.05884,
#   'longitude': 140.653,
#   'iso639-3': 'yet'},
#  'hata1242': {'name': 'Hatam-Mansim',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'araf1243': {'name': 'Arafundi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': 'arf'},
#  'movi1243': {'name': 'Movima',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -13.8115,
#   'longitude': -65.6348,
#   'iso639-3': 'mzp'},
#  'tamb1257': {'name': 'Tambora',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -8.25,
#   'longitude': 118.0,
#   'iso639-3': 'xxt'},
#  'buna1274': {'name': 'Bunaban',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'teme1251': {'name': 'Temeinic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cuit1236': {'name': 'Cuitlatec',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 18.1,
#   'longitude': -100.5,
#   'iso639-3': 'cuy'},
#  'muni1258': {'name': 'Muniche',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -5.7441796,
#   'longitude': -76.426712,
#   'iso639-3': 'myr'},
#  'sout1293': {'name': 'South-Eastern Tasmanian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'taia1239': {'name': 'Taiap',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.05047,
#   'longitude': 144.506,
#   'iso639-3': 'gpn'},
#  'chiq1253': {'name': 'Chiquitano',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'chim1301': {'name': 'Chimariko',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 41.0,
#   'longitude': -123.0,
#   'iso639-3': 'cid'},
#  'klam1254': {'name': 'Klamath-Modoc',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 42.5861,
#   'longitude': -121.704,
#   'iso639-3': 'kla'},
#  'yuru1243': {'name': 'Yurumanguí',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 3.436864,
#   'longitude': -76.522636,
#   'iso639-3': nan},
#  'uruc1242': {'name': 'Uru-Chipaya',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'west2604': {'name': 'West Bomberai',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nduu1242': {'name': 'Ndu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'anga1289': {'name': 'Angan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'coah1252': {'name': 'Coahuilteco',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 28.2589,
#   'longitude': -97.89,
#   'iso639-3': 'xcw'},
#  'pomo1273': {'name': 'Pomoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mixe1287': {'name': 'Mixed Language',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'aust1307': {'name': 'Austronesian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cayu1262': {'name': 'Cayubaba',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -13.2482,
#   'longitude': -65.4822,
#   'iso639-3': 'cyb'},
#  'east1459': {'name': "East Bird's Head",
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yeni1252': {'name': 'Yeniseian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'toto1251': {'name': 'Totonacan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yama1264': {'name': 'Yámana',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -55.2748,
#   'longitude': -68.2648,
#   'iso639-3': 'yag'},
#  'arti1236': {'name': 'Artificial Language',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kunz1244': {'name': 'Kunza',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -23.0,
#   'longitude': -69.0,
#   'iso639-3': 'kuz'},
#  'mail1249': {'name': 'Mailuan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'shom1245': {'name': 'Shom Peng',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 7.02099,
#   'longitude': 93.8064,
#   'iso639-3': 'sii'},
#  'iber1250': {'name': 'Iberian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 40.624,
#   'longitude': 0.212401,
#   'iso639-3': 'xib'},
#  'nucl1710': {'name': 'Nuclear-Macro-Je',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'boro1281': {'name': 'Bororoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bira1253': {'name': 'Ongota',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 5.29807,
#   'longitude': 37.025,
#   'iso639-3': 'bxe'},
#  'lule1238': {'name': 'Lule',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -25.221839,
#   'longitude': -61.887818,
#   'iso639-3': 'ule'},
#  'hara1260': {'name': 'Harakmbut',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yele1255': {'name': 'Yele',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -11.3796,
#   'longitude': 154.127,
#   'iso639-3': 'yle'},
#  'miwo1274': {'name': 'Miwok-Costanoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pauw1244': {'name': 'Pauwasi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pele1245': {'name': 'Pele-Ata',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -5.58045,
#   'longitude': 151.05,
#   'iso639-3': 'ata'},
#  'left1242': {'name': 'Left May',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'lowe1437': {'name': 'Lower Sepik-Ramu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mang1423': {'name': 'Mangarrayi-Maran',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'hurr1239': {'name': 'Hurro-Urartian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'krua1234': {'name': 'Kru',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'iton1250': {'name': 'Itonama',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -12.80431,
#   'longitude': -64.35748,
#   'iso639-3': 'ito'},
#  'guai1237': {'name': 'Guaicurian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 24.1666666667,
#   'longitude': -110.3,
#   'iso639-3': nan},
#  'tonk1249': {'name': 'Tonkawa',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 30.25,
#   'longitude': -96.75,
#   'iso639-3': 'tqw'},
#  'araw1281': {'name': 'Arawakan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'piaw1238': {'name': 'Piawi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'chuk1271': {'name': 'Chukotko-Kamchatkan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kond1302': {'name': 'Konda-Yahadian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'usku1243': {'name': 'Usku',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -3.63853,
#   'longitude': 140.502,
#   'iso639-3': 'ulf'},
#  'guah1252': {'name': 'Guahiboan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'maku1246': {'name': 'Máku',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 3.969231,
#   'longitude': -64.235892,
#   'iso639-3': 'xak'},
#  'timo1261': {'name': 'Timor-Alor-Pantar',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'iroq1247': {'name': 'Iroquoian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'jiva1245': {'name': 'Chicham',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'jarr1235': {'name': 'Jarrakan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'haid1248': {'name': 'Haida',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': 'hai'},
#  'atak1252': {'name': 'Atakapa',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 30.9121,
#   'longitude': -93.0827,
#   'iso639-3': 'aqp'},
#  'nort1547': {'name': 'Northern Daly',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'adai1235': {'name': 'Adai',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 31.6314,
#   'longitude': -92.0059,
#   'iso639-3': 'xad'},
#  'lavu1241': {'name': 'Lavukaleve',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -9.05569,
#   'longitude': 159.119,
#   'iso639-3': 'lvk'},
#  'east2503': {'name': 'Eastern Trans-Fly',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'molo1262': {'name': 'Molof',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -3.41946,
#   'longitude': 140.557,
#   'iso639-3': 'msl'},
#  'sout1516': {'name': "South Bird's Head Family",
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tuxa1239': {'name': 'Tuxá',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -8.953642,
#   'longitude': -38.2742287,
#   'iso639-3': 'tud'},
#  'wara1303': {'name': 'Warao',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 7.50851,
#   'longitude': -59.3528,
#   'iso639-3': 'wba'},
#  'pidg1258': {'name': 'Pidgin',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'ainu1252': {'name': 'Ainu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yang1287': {'name': 'Yangmanic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'beot1247': {'name': 'Beothuk',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 48.0,
#   'longitude': -57.0,
#   'iso639-3': 'bue'},
#  'abkh1242': {'name': 'Abkhaz-Adyge',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'jica1245': {'name': 'Jicaquean',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'saus1247': {'name': 'Sause',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -3.16632,
#   'longitude': 139.627,
#   'iso639-3': 'sao'},
#  'sign1238': {'name': 'Sign Language',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'khoe1240': {'name': 'Khoe-Kwadi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'misu1242': {'name': 'Misumalpan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kimk1238': {'name': 'Kimki',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.2742,
#   'longitude': 140.884,
#   'iso639-3': 'sbt'},
#  'puri1261': {'name': 'Puri-Coroado',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'fasu1242': {'name': 'Fasu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -6.62687,
#   'longitude': 143.284,
#   'iso639-3': 'faa'},
#  'kaya1327': {'name': 'Kayagaric',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sout2772': {'name': 'Southern Daly',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'coos1248': {'name': 'Coosan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'buru1296': {'name': 'Burushaski',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 36.2161,
#   'longitude': 74.8236,
#   'iso639-3': 'bsk'},
#  'mure1235': {'name': 'Mure',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -13.636709,
#   'longitude': -62.2020909,
#   'iso639-3': nan},
#  'taik1256': {'name': 'Tai-Kadai',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'zamu1243': {'name': 'Zamucoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cofa1242': {'name': 'Cofán',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 0.276675,
#   'longitude': -77.0643,
#   'iso639-3': 'con'},
#  'algi1248': {'name': 'Algic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'coto1248': {'name': 'Cotoname',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 25.9116,
#   'longitude': -97.3956,
#   'iso639-3': 'xcn'},
#  'skoo1245': {'name': 'Sko',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'iran1263': {'name': 'Irántxe-Münkü',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -12.7178,
#   'longitude': -57.9806,
#   'iso639-3': 'irn'},
#  'naml1239': {'name': 'Namla-Tofanma',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'chit1248': {'name': 'Chitimacha',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 30.3386,
#   'longitude': -90.9123,
#   'iso639-3': 'ctm'},
#  'guai1249': {'name': 'Guaicuruan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'wage1238': {'name': 'Wageman',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -13.8627,
#   'longitude': 131.893,
#   'iso639-3': 'waq'},
#  'toro1256': {'name': 'Tor-Orya',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'peba1241': {'name': 'Peba-Yagua',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'lara1258': {'name': 'Laragia',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -12.4111,
#   'longitude': 130.922,
#   'iso639-3': 'lrg'},
#  'bord1247': {'name': 'Border',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mawe1251': {'name': 'Mawes',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -2.36944,
#   'longitude': 139.752,
#   'iso639-3': 'mgk'},
#  'ayma1253': {'name': 'Aymaran',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'soma1242': {'name': 'Somahai',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'daga1274': {'name': 'Dagan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mass1263': {'name': 'Massep',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -1.74679,
#   'longitude': 138.294,
#   'iso639-3': 'mvs'},
#  'pank1250': {'name': 'Pankararú',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -8.99999,
#   'longitude': -37.0167,
#   'iso639-3': 'paz'},
#  'chib1249': {'name': 'Chibchan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nyul1248': {'name': 'Nyulnyulan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'wiru1244': {'name': 'Wiru',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -6.35863,
#   'longitude': 144.214,
#   'iso639-3': 'wiu'},
#  'taua1242': {'name': 'Tauade',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -8.3486,
#   'longitude': 147.094,
#   'iso639-3': 'ttd'},
#  'wadj1254': {'name': 'Wadjiginy',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -12.8596,
#   'longitude': 130.737,
#   'iso639-3': 'wdj'},
#  'lenc1239': {'name': 'Lencan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'siou1252': {'name': 'Siouan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nort2923': {'name': 'North Halmahera',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kiow1265': {'name': 'Kiowa-Tanoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'puin1248': {'name': 'Puinave',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 3.92974,
#   'longitude': -67.6886,
#   'iso639-3': 'pui'},
#  'kres1240': {'name': 'Kresh-Aja',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kamu1264': {'name': 'Kamula-Elevala',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'chin1490': {'name': 'Chinookan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'huit1251': {'name': 'Huitotoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kxaa1236': {'name': 'Kxa',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'quec1387': {'name': 'Quechuan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'dibi1240': {'name': 'Dibiyaso',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -7.82096,
#   'longitude': 142.779,
#   'iso639-3': 'dby'},
#  'sulk1246': {'name': 'Sulka',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -5.03471,
#   'longitude': 151.891,
#   'iso639-3': 'sua'},
#  'yuka1259': {'name': 'Yukaghir',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kart1248': {'name': 'Kartvelian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'east2499': {'name': 'East Kutubu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'west1493': {'name': "West Bird's Head",
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pyuu1245': {'name': 'Pyu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.45003,
#   'longitude': 141.018,
#   'iso639-3': 'pby'},
#  'kadu1256': {'name': 'Kadugli-Krongo',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yale1246': {'name': 'Yale',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -3.79762,
#   'longitude': 141.566,
#   'iso639-3': 'nce'},
#  'kala1402': {'name': 'Kalapuyan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'seri1257': {'name': 'Seri',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 28.9877,
#   'longitude': -112.384,
#   'iso639-3': 'sei'},
#  'saha1256': {'name': 'Saharan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pano1259': {'name': 'Pano-Tacanan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'beto1236': {'name': 'Betoi-Jirara',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 7.223906,
#   'longitude': -71.420238,
#   'iso639-3': nan},
#  'nort1442': {'name': 'North-Eastern Tasmanian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yawa1259': {'name': 'Yawa-Saweru',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sino1245': {'name': 'Sino-Tibetan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'atac1235': {'name': 'Atacame',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 0.834931,
#   'longitude': -79.778137,
#   'iso639-3': nan},
#  'ticu1244': {'name': 'Ticuna-Yuri',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'geel1240': {'name': 'Geelvink Bay',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cams1241': {'name': 'Camsá',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 1.14537,
#   'longitude': -76.8931,
#   'iso639-3': 'kbh'},
#  'cent2045': {'name': 'Jalaa',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 9.59433,
#   'longitude': 11.5853,
#   'iso639-3': 'cet'},
#  'manu1261': {'name': 'Manubaran',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'take1257': {'name': 'Takelma',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 42.423,
#   'longitude': -123.452,
#   'iso639-3': 'tkm'},
#  'pama1250': {'name': 'Pama-Nyungan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'ando1256': {'name': 'Andoque',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -0.53751,
#   'longitude': -72.0869,
#   'iso639-3': 'ano'},
#  'pira1253': {'name': 'Pirahã',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -6.77713,
#   'longitude': -61.8167,
#   'iso639-3': 'myp'},
#  'boga1247': {'name': 'Bogaya',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -5.54487,
#   'longitude': 142.255,
#   'iso639-3': 'boq'},
#  'moch1259': {'name': 'Mochica',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -8.01667,
#   'longitude': -79.0,
#   'iso639-3': 'omc'},
#  'come1251': {'name': 'Comecrudan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 26.1333,
#   'longitude': -98.4667,
#   'iso639-3': 'xcm'},
#  'gumu1250': {'name': 'Gumuz',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mimi1240': {'name': 'Mimi-Gaudefroy',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 13.827507,
#   'longitude': 21.11324,
#   'iso639-3': nan},
#  'amto1249': {'name': 'Amto-Musan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'limi1242': {'name': 'Limilngan-Wulna',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cent2225': {'name': 'Central Sudanic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'iwai1246': {'name': 'Iwaidjan Proper',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sand1273': {'name': 'Sandawe',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': -5.26918,
#   'longitude': 35.4808,
#   'iso639-3': 'sad'},
#  'eski1264': {'name': 'Eskimo-Aleut',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'leco1242': {'name': 'Leco',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -15.0092,
#   'longitude': -67.8818,
#   'iso639-3': 'lec'},
#  'chum1262': {'name': 'Chumashan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'otii1244': {'name': 'Oti',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -24.3153231,
#   'longitude': -50.5580261,
#   'iso639-3': 'oti'},
#  'gong1255': {'name': 'Ta-Ne-Omotic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tara1323': {'name': 'Tarascan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sech1236': {'name': 'Sechuran',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -5.568969,
#   'longitude': -80.828247,
#   'iso639-3': nan},
#  'nyim1244': {'name': 'Nyimang',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'grea1241': {'name': 'Great Andamanese',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'xuku1239': {'name': 'Xukurú',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -8.6606156,
#   'longitude': -37.0869089,
#   'iso639-3': 'xoo'},
#  'alse1251': {'name': 'Alsea-Yaquina',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 44.408,
#   'longitude': -123.94,
#   'iso639-3': 'aes'},
#  'tuuu1241': {'name': 'Tuu',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tura1263': {'name': 'Turama-Kikori',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'monu1249': {'name': 'Bogia',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'jara1244': {'name': 'Jarawa-Onge',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cayu1241': {'name': 'Cayuse',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 46.1136,
#   'longitude': -117.94,
#   'iso639-3': 'xcy'},
#  'pume1238': {'name': 'Pumé',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 7.10677,
#   'longitude': -67.5996,
#   'iso639-3': 'yae'},
#  'chon1288': {'name': 'Chonan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'savo1255': {'name': 'Savosavo',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -9.12853,
#   'longitude': 159.814,
#   'iso639-3': 'svs'},
#  'tiwi1244': {'name': 'Tiwi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -11.6308,
#   'longitude': 130.949,
#   'iso639-3': 'tiw'},
#  'gaga1251': {'name': 'Gaagudju',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -12.5176,
#   'longitude': 132.643,
#   'iso639-3': 'gbu'},
#  'char1238': {'name': 'Charruan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sius1254': {'name': 'Siuslaw',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 42.5111,
#   'longitude': -124.379,
#   'iso639-3': 'sis'},
#  'umbu1235': {'name': 'Umbugarla',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -12.9325,
#   'longitude': 131.825,
#   'iso639-3': 'umr'},
#  'doso1238': {'name': 'Doso-Turumsa',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mero1237': {'name': 'Meroitic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 16.9333,
#   'longitude': 33.7333,
#   'iso639-3': 'xmr'},
#  'taus1253': {'name': 'Taushiro',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -3.22497,
#   'longitude': -75.5603,
#   'iso639-3': 'trr'},
#  'yana1271': {'name': 'Yana',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 39.2769,
#   'longitude': -121.608,
#   'iso639-3': 'ynn'},
#  'gule1241': {'name': 'Gule',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 11.8336,
#   'longitude': 33.6929,
#   'iso639-3': 'gly'},
#  'cahu1265': {'name': 'Cahuapanan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'more1255': {'name': 'Yam',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'west2434': {'name': 'Western Daly',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'urar1246': {'name': 'Urarina',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -4.44006,
#   'longitude': -75.4211,
#   'iso639-3': 'ura'},
#  'wint1258': {'name': 'Wintuan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'wash1253': {'name': 'Washo',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 38.8184,
#   'longitude': -119.64,
#   'iso639-3': 'was'},
#  'pala1350': {'name': 'Palaihnihan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pura1257': {'name': 'Purari',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -7.59133,
#   'longitude': 145.036,
#   'iso639-3': 'iar'},
#  'mong1349': {'name': 'Mongolic-Khitan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'waka1280': {'name': 'Wakashan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sout2845': {'name': 'South Omotic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tini1245': {'name': 'Tinigua',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 2.716,
#   'longitude': -73.768,
#   'iso639-3': 'tit'},
#  'aust1305': {'name': 'Austroasiatic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'aika1237': {'name': 'Aikanã',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -12.6695,
#   'longitude': -60.5353,
#   'iso639-3': 'tba'},
#  'yera1243': {'name': 'Yerakai',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.28828,
#   'longitude': 142.947,
#   'iso639-3': 'yra'},
#  'nucl1580': {'name': 'Eleman',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sena1264': {'name': 'Senagi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'suki1244': {'name': 'Suki-Gogodala',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tung1282': {'name': 'Tungusic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'choc1280': {'name': 'Chocoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'uncl1493': {'name': 'Unclassifiable',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'laal1242': {'name': 'Laal',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 10.0063,
#   'longitude': 17.6143,
#   'iso639-3': 'gdm'},
#  'oyst1235': {'name': 'Oyster Bay-Big River-Little Swanport',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Australia',
#   'latitude': -42.307378,
#   'longitude': 147.50061,
#   'iso639-3': nan},
#  'turk1311': {'name': 'Turkic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'else1239': {'name': 'Elseng',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -3.00176,
#   'longitude': 140.418,
#   'iso639-3': 'mrf'},
#  'kawe1237': {'name': 'Kawesqar',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kwal1257': {'name': 'Kwalean',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tana1288': {'name': 'Tanahmerah',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -2.5523,
#   'longitude': 133.18,
#   'iso639-3': 'tcm'},
#  'kuna1268': {'name': 'Kunama',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 14.5879,
#   'longitude': 37.5292,
#   'iso639-3': 'kun'},
#  'otom1276': {'name': 'Otomaco-Taparita',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 7.869912,
#   'longitude': -70.997315,
#   'iso639-3': nan},
#  'maib1239': {'name': 'Maybrat-Karon',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -1.3679,
#   'longitude': 132.591,
#   'iso639-3': 'ayz'},
#  'kara1497': {'name': 'Karami',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -7.13333,
#   'longitude': 143.117,
#   'iso639-3': 'xar'},
#  'siam1242': {'name': 'Siamou',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 10.998,
#   'longitude': -4.92143,
#   'iso639-3': 'sif'},
#  'tupi1275': {'name': 'Tupian',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kuja1239': {'name': 'Kujarge',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 11.7473,
#   'longitude': 22.1956,
#   'iso639-3': 'vkj'},
#  'abun1252': {'name': 'Abun',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -0.57073,
#   'longitude': 132.416,
#   'iso639-3': 'kgr'},
#  'cand1248': {'name': 'Candoshi-Shapra',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -4.23835,
#   'longitude': -76.9347,
#   'iso639-3': 'cbu'},
#  'dizo1235': {'name': 'Dizoid',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'hatt1246': {'name': 'Hattic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 40.4,
#   'longitude': 34.6,
#   'iso639-3': 'xht'},
#  'kena1236': {'name': 'Kenaboi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 3.154162,
#   'longitude': 102.01596,
#   'iso639-3': 'xbn'},
#  'basq1248': {'name': 'Basque',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Eurasia',
#   'latitude': 43.2787,
#   'longitude': -1.31622,
#   'iso639-3': 'eus'},
#  'gunw1250': {'name': 'Gunwinyguan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mixe1284': {'name': 'Mixe-Zoque',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yano1268': {'name': 'Yanomamic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nada1235': {'name': 'Naduhup',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mair1253': {'name': 'Mairasic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'atha1245': {'name': 'Athabaskan-Eyak-Tlingit',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kano1245': {'name': 'Kanoê',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': -12.1789,
#   'longitude': -64.5812,
#   'iso639-3': 'kxo'},
#  'kore1284': {'name': 'Koreanic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'yuwa1244': {'name': 'Hoti',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 5.63879,
#   'longitude': -65.4267,
#   'iso639-3': 'yau'},
#  'araw1282': {'name': 'Arawan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'papi1255': {'name': 'Papi',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -4.4725,
#   'longitude': 142.011,
#   'iso639-3': 'ppe'},
#  'atla1278': {'name': 'Atlantic-Congo',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'timo1237': {'name': 'Timote-Cuica',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'South America',
#   'latitude': 8.848165,
#   'longitude': -70.975342,
#   'iso639-3': nan},
#  'worr1236': {'name': 'Worrorran',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'morb1239': {'name': 'Mor (Bomberai Peninsula)',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -2.85747,
#   'longitude': 132.845,
#   'iso639-3': 'moq'},
#  'timu1245': {'name': 'Timucua',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 30.3027,
#   'longitude': -82.3132,
#   'iso639-3': 'tjm'},
#  'kwer1242': {'name': 'Greater Kwerba',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cadd1255': {'name': 'Caddoan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mani1293': {'name': 'Maningrida',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'moro1289': {'name': 'Marori',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -8.5692,
#   'longitude': 140.688,
#   'iso639-3': 'mok'},
#  'heib1242': {'name': 'Heibanic',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'anim1240': {'name': 'Anim',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'xinc1237': {'name': 'Xincan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sali1253': {'name': 'Salinan',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'North America',
#   'latitude': 37.6646,
#   'longitude': -121.718,
#   'iso639-3': 'sln'},
#  'bilu1245': {'name': 'Bilua',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -7.92388,
#   'longitude': 156.663,
#   'iso639-3': 'blb'},
#  'yuat1252': {'name': 'Yuat',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kaur1274': {'name': 'Kaure-Kosare',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'dogo1299': {'name': 'Dogon',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nort2933': {'name': 'North Bougainville',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bert1248': {'name': 'Berta',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Africa',
#   'latitude': 10.6474,
#   'longitude': 34.7042,
#   'iso639-3': 'wti'},
#  'sepi1257': {'name': 'Sepik',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'spee1234': {'name': 'Speech Register',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'koma1264': {'name': 'Koman',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kibi1239': {'name': 'Kibiri',
#   'family_id': nan,
#   'top-level family': nan,
#   'macroarea': 'Papunesia',
#   'latitude': -7.45276,
# ...
#   'longitude': 121.04764,
#   'iso639-3': 'ssq'},
#  'ngin1248': {'name': 'Nginamanu',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'namu1248': {'name': 'Namut',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'ende1247': {'name': 'Ende-Lio',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nage1238': {'name': 'Nage-Keo',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'lioo1240': {'name': "Li'o",
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -8.68615,
#   'longitude': 121.832,
#   'iso639-3': 'ljl'},
#  'ende1246': {'name': 'Ende',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -8.70998,
#   'longitude': 121.555,
#   'iso639-3': 'end'},
#  'west2925': {'name': "Western Li'o",
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'east2840': {'name': "Eastern Li'o",
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nang1264': {'name': 'Nangapanda',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mauk1239': {'name': 'Maukauro',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'keoo1238': {'name': 'Kéo',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -8.8704,
#   'longitude': 121.256,
#   'iso639-3': 'xxk'},
#  'nage1237': {'name': 'Nage',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -8.70513,
#   'longitude': 121.31,
#   'iso639-3': 'nxe'},
#  'ngao1245': {'name': "Nga'o",
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cent2355': {'name': 'Central Nage',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'east2838': {'name': 'Eastern Nage',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kawi1241': {'name': 'Kawi',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -7.0,
#   'longitude': 111.0,
#   'iso639-3': 'kaw'},
#  'mode1251': {'name': 'Modern Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'java1254': {'name': 'Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -7.001,
#   'longitude': 109.287,
#   'iso639-3': 'jav'},
#  'teng1272': {'name': 'Tengger',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -7.89069,
#   'longitude': 113.037,
#   'iso639-3': 'tes'},
#  'newc1244': {'name': 'New Caledonian Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -22.3001,
#   'longitude': 166.445,
#   'iso639-3': 'jas'},
#  'osin1237': {'name': 'Osing',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -8.25262,
#   'longitude': 114.292,
#   'iso639-3': 'osi'},
#  'cari1276': {'name': 'Caribbean Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'South America',
#   'latitude': 5.62695,
#   'longitude': -54.6305,
#   'iso639-3': 'jvn'},
#  'jawa1239': {'name': 'Jawa Halus',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'east2487': {'name': 'East Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cent2331': {'name': 'Central Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'west2565': {'name': 'West Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'arek1234': {'name': 'Arekan',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'jomb1234': {'name': 'Jombang',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'mala1493': {'name': 'Malang-Pasuruan',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sura1245': {'name': 'Surabaya',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sema1270': {'name': 'Semarang (Central Javanese)',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'kedu1234': {'name': 'Kedu',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'temb1273': {'name': 'Mataraman',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'blor1234': {'name': 'Blora',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'madi1264': {'name': 'Madiunan',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bany1247': {'name': 'Banyumas',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bage1239': {'name': 'Bagelen',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pasi1258': {'name': 'Pesisir Lor',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'solo1259': {'name': 'Solo',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'east2801': {'name': 'Eastern North-Coast Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'pema1234': {'name': 'Pemalang',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'peka1244': {'name': 'Pekalongan',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tega1246': {'name': 'Tegal',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'indr1248': {'name': 'Indramayu',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bant1291': {'name': 'Banten (West Javanese)',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cire1240': {'name': 'Cirebon Javanese',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -6.74533,
#   'longitude': 108.538,
#   'iso639-3': nan},
#  'gayo1244': {'name': 'Gayo',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 4.3733,
#   'longitude': 97.3456,
#   'iso639-3': 'gay'},
#  'toba1265': {'name': 'Batakic',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nucl1463': {'name': 'Nuclear Barrier Islands',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'doro1264': {'name': 'Dorot',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tamp1253': {'name': 'Tampur',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'serb1268': {'name': 'Serbodjadi',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'boba1247': {'name': 'Bobasan',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sout3166': {'name': 'Southern Batak',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nort2831': {'name': 'Northern Batak',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sout2849': {'name': 'Tobaic',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bata1288': {'name': 'Batak Simalungun',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 3.04372,
#   'longitude': 98.9083,
#   'iso639-3': 'bts'},
#  'angk1248': {'name': 'Angkola-Mandailing',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'bata1289': {'name': 'Batak Toba',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 2.35498,
#   'longitude': 99.1761,
#   'iso639-3': 'bbc'},
#  'bata1290': {'name': 'Batak Angkola',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 1.66127,
#   'longitude': 99.60248,
#   'iso639-3': 'akb'},
#  'bata1291': {'name': 'Batak Mandailing',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 0.85805,
#   'longitude': 99.898,
#   'iso639-3': 'btm'},
#  'bata1293': {'name': 'Batak Karo',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 2.12787,
#   'longitude': 98.2517,
#   'iso639-3': 'btx'},
#  'bata1294': {'name': 'Batak Dairi',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 2.51438,
#   'longitude': 98.2427,
#   'iso639-3': 'btd'},
#  'bata1292': {'name': 'Batak Alas-Kluet',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 3.4293,
#   'longitude': 97.8123,
#   'iso639-3': 'btz'},
#  'sing1240': {'name': 'Singkil',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'alas1254': {'name': 'Alas',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'ment1248': {'name': 'Mentawai-Nias-Sikule',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sime1241': {'name': 'Simeulue',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 2.50288,
#   'longitude': 96.2757,
#   'iso639-3': 'smr'},
#  'nias1241': {'name': 'Nias-Sikule',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': nan,
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'ment1249': {'name': 'Mentawai',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': -1.41092,
#   'longitude': 98.9401,
#   'iso639-3': 'mwv'},
#  'siku1242': {'name': 'Sikule',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 2.69113,
#   'longitude': 95.9636,
#   'iso639-3': 'skh'},
#  'nias1242': {'name': 'Nias',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': 0.90691,
#   'longitude': 97.4961,
#   'iso639-3': 'nia'},
#  'leko1247': {'name': 'Lekon',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'tapa1258': {'name': 'Tapah',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'batu1257': {'name': 'Nias Selatan',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'nucl1464': {'name': 'Nias Utara',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'cent2397': {'name': 'Central Nias',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sout2848': {'name': 'South Siberut',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sipu1239': {'name': 'Sipura',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sima1259': {'name': 'Simalegi',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'saum1237': {'name': 'Saumanganja',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'paga1237': {'name': 'Pagai',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'sila1249': {'name': 'Silabu',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  'taik1253': {'name': 'Taikaku',
#   'family_id': 'aust1307',
#   'top-level family': 'Austronesian',
#   'macroarea': 'Papunesia',
#   'latitude': nan,
#   'longitude': nan,
#   'iso639-3': nan},
#  ...}

# %%
language_all["parent_name"]= language_all["parent"].apply(lambda x: langd[x]["name"] if x in langd else np.NaN)

# %%
language_all["id"]=language_all.index

# %%
language_all["family"]=language_all["id"].apply(lambda x: langd[x]["top-level family"] if x in langd else np.NaN)

# %%
language_all["family_id"]=language_all["id"].apply(lambda x: langd[x]["family_id"] if x in langd else np.NaN)

# %%
language_all["macroarea"]= language_all["macroareas"].apply(lambda x: literal_eval(x)[0] if len(literal_eval(x))>0 else np.NaN)

# %%
language_all.to_csv("../data/languages/languages_all.csv")

# %%
# langdict = language_all.to_dict(orient="index")

# %%
langdict["dutc1256"]["macroarea"]
# Out:
# 'Eurasia'

# %%
import json
with open("../data/stage1/language_contacts_nr/dutc1256.json") as f:
    d = json.load(f)

# %%
print("dutc1256", lang_dict["dutc1256"]["name"], lang_dict["dutc1256"]["latitude"], lang_dict["dutc1256"]["longitude"])
for lang , dist in d["dutc1256"].items():
    if dist<=9:
        print(lang, lang_dict[lang]["name"], dist, lang_dict[lang]["latitude"], lang_dict[lang]["longitude"])
# d["dutc1256"]["stan1295"]

# %% [markdown]
# ## load colex information

# %%
df = pd.read_csv(f"{stage1}/colex_pmi/clics3_nuclear.csv")

# %%
df_pmi = df[["source", "target", "weight", "target_nr", "source_nr", "pmi"]]

# %%
df_pmi.head(2)
# Out:
#      source    target  weight  target_nr  source_nr       pmi
# 0  nege1244  pume1238       2         21         14  5.542637
# 1  lakk1238  nege1244       2          9         21  6.180067

# %%
colex_nr_dict = dict()

for source, target, source_nr, target_nr in zip(df_pmi["source"],df_pmi["target"], df_pmi["source_nr"], df_pmi["target_nr"]):
    if source not in colex_nr_dict:
        colex_nr_dict[source]=source_nr
    if target not in colex_nr_dict:
        colex_nr_dict[target]=target_nr

# %%
colex_dict = dict()

for source, target, weight, pmi in zip(df_pmi["source"],df_pmi["target"], df_pmi["weight"], df_pmi["pmi"]):
    t1,t2 = sorted([source, target])
    colex_dict[(t1,t2)]= (weight, pmi)

# %%
colex_dict['nege1244', 'pume1238']
# Out:
# (2, 5.542637091247636)

# %%
len(colex_nr_dict)
# Out:
# 1129

# %%
colex_nr_dict["nege1244"]
# Out:
# 14

# %% [markdown]
# ## load geo graph

# %%
with open(f"{stage1}/language_geo_graph.pickle", "rb") as f:
    graph = pickle.load(f)

# %%
graph.edges['guin1254', 'pawa1255']
# Out:
# {'contact': 1242, 'geodist': 17172.307067554568}

# %%
graph.nodes["guin1254"]
# Out:
# {'coord': (7.93196, -8.98843)}

# %%
len(graph.nodes), len(graph.edges)
# Out:
# (1561, 1217580)

# %% [markdown]
# # 2.Populate graph with colex, phon and lang information

# %%
g = nx.Graph()

g.graph["dataset"]="clics3"
g.graph["wordlist"]="nuclear"

# %% [markdown]
# ### 2.1 add node attributes

# %% [markdown]
# - get from colexifications.
# - name, family, parent, branch, colex_nr

# %%
literal_eval(langdict["nege1244"]["timespan"])
# Out:
# {'start_year': 1700,
#  'start_month': 1,
#  'start_day': 1,
#  'end_year': 1987,
#  'end_month': 1,
#  'end_day': 1}

# %%
for lang, colex_nr in colex_nr_dict.items():
    if lang in langdict:
        node_dict = langdict[lang] # geo information
        name = node_dict["name"]
        fam = node_dict["family"]
        parent = node_dict["parent_name"]
        branch = node_dict["branch"]
        iso_code = node_dict["iso639_3"]
        lat = node_dict["latitude"]
        long=node_dict["longitude"]
        area = node_dict["macroarea"]
        times=[]
        if str(node_dict["timespan"])!="nan":
            
            timespan = literal_eval(node_dict["timespan"])
            start_year= timespan["start_year"]
            times.append(start_year)
            end_year=timespan["end_year"]
            times.append(end_year)
        
       
        nr_colex = colex_nr_dict[lang]
        
        g.add_node(lang, 
                   colex_nr = nr_colex,
                   name=name,
                   family= fam,
                   parent= parent,
                   branch= branch,
                   iso3 = iso_code,
                   area = area,
                   timespan = tuple(times),
                   coord= (lat, long))

# %%
g.nodes["nege1244"]
# Out:
# {'colex_nr': 14,
#  'name': 'Negerhollands',
#  'family': 'Indo-European',
#  'parent': 'Zeeuwic',
#  'branch': 'Global Dutch',
#  'iso3': 'dcr',
#  'area': 'North America',
#  'timespan': (1700, 1987),
#  'coord': (18.3416, -64.8922)}

# %%
g.nodes["nepa1254"]
# Out:
# {'colex_nr': 9,
#  'name': 'Nepali',
#  'family': 'Indo-European',
#  'parent': 'Eastern Pahari',
#  'branch': 'Eastern Pahari',
#  'iso3': 'npi',
#  'area': 'Eurasia',
#  'timespan': (),
#  'coord': (28.0, 85.0)}

# %%
g.edges['cofa1242', 'muba1238']
# Out:
# {'phon_pmi': 0.8228045110425997,
#  'colex_pmi': 6.654846594833661,
#  'weight': 1,
#  'contact': 1000,
#  'geodist': 15518.142529426157,
#  'neighbour': False}

# %% [markdown]
# ### 2.2 add edges and attributes

# %%
phon_dict['bafi1243', 'pall1244']
# Out:
# 0.8399546217176125

# %%
intersected_langs = set(colex_dict.keys()).intersection(set(phon_dict.keys()))
len(intersected_langs)
# Out:
# 34519

# %%
intersected_langs

# %%
len(set(colex_dict.keys())), len(set(phon_dict.keys()))
# Out:
# (167142, 726975)

# %%
for edge in graph.edges:
    contact = graph.edges[edge]["contact"]
    geodist = graph.edges[edge]["geodist"]
    if edge in g.edges:
        g.edges[edge]["contact"]=contact
        g.edges[edge]["geodist"]=geodist
        if contact <10:
            g.edges[edge]["neighbour"]=True
        else:
            g.edges[edge]["neighbour"]=False

# %%
len(g.edges), len(g.nodes)
# Out:
# (859598, 2068)

# %% [markdown]
# - on the edges: phon_pmi, colex_pmi, colex_weight, geo_contact, geo_dist, geo_neighbour, branch (Same?)

# %%
for langp, phon_pmi in phon_dict.items():
    l1,l2 = langp
    g.add_edge(l1,l2, phon_pmi= phon_pmi)

# %%
('pume1238', 'bafi1243') in g.edges
# Out:
# True

# %%
g.edges['pume1238', 'bafi1243']
# Out:
# {'phon_pmi': 0.865793672052637}

# %%
g.edges['bafi1243','pume1238']
# Out:
# {'phon_pmi': 0.865793672052637}

# %%
for langp, colex_pmi_ in colex_dict.items():
    l1,l2 = langp
    weight, pmi = colex_pmi_
    if (l1,l2) in g.edges:
        g.edges[l1,l2]["colex_pmi"]=pmi
        g.edges[l1,l2]["weight"]=weight
    else:
        g.add_edge(l1,l2, colex_pmi=pmi, weight=weight)

# %%
g.edges['nepa1254', 'yuga1244']
# Out:
# {'phon_pmi': 0.8599357983068425, 'colex_pmi': 8.34999201330524, 'weight': 1}
